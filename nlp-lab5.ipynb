# %%
import nltk
text = nltk.word_tokenize("And now for something completely different") 
nltk.pos_tag(text)
# Out:
# [('And', 'CC'),
#  ('now', 'RB'),
#  ('for', 'IN'),
#  ('something', 'NN'),
#  ('completely', 'RB'),
#  ('different', 'JJ')]

# %%
nltk.help.upenn_tagset('RB')
# Out:
# RB: adverb
#     occasionally unabatingly maddeningly adventurously professedly
#     stirringly prominently technologically magisterially predominately
#     swiftly fiscally pitilessly ...

# %%
text = nltk.word_tokenize("They refuse to permit us to obtain the refuse permit")
nltk.pos_tag(text)
# Out:
# [('They', 'PRP'),
#  ('refuse', 'VBP'),
#  ('to', 'TO'),
#  ('permit', 'VB'),
#  ('us', 'PRP'),
#  ('to', 'TO'),
#  ('obtain', 'VB'),
#  ('the', 'DT'),
#  ('refuse', 'NN'),
#  ('permit', 'NN')]

# %%
text = nltk.Text(word.lower() for word in nltk.corpus.brown.words())
text.similar('woman')
# Out:
# man time day year car moment world house family child country boy
# state job place way war girl work word

# %%
text.similar('bought')
# Out:
# made said done put had seen found given left heard was been brought
# set got that took in told felt

# %%
text.similar('over')
# Out:
# in on to of and for with from at by that into as up out down through
# is all about

# %%
text.similar('the')
# Out:
# a his this their its her an that our any all one these my in your no
# some other and

# %%
text.similar('up')
# Out:
# in out on down to back and from for off over of by at it into as that
# with was

# %%
text.similar('down')
# Out:
# in up on out to back and over into for at from is with around all of
# off by as

# %%
from nltk.corpus import brown
brown_tagged_sents = brown.tagged_sents(categories='news')
brown_sents = brown.sents(categories='news')

# %%
tags = [tag for (word, tag) in brown.tagged_words(categories='news')]
nltk.FreqDist(tags).max()
# Out:
# 'NN'

# %%
raw = 'I do not like green eggs and ham, I do not like them Sam I am!' 
tokens = nltk.word_tokenize(raw) 
default_tagger = nltk.DefaultTagger('NN')
default_tagger.tag(tokens)
# Out:
# [('I', 'NN'),
#  ('do', 'NN'),
#  ('not', 'NN'),
#  ('like', 'NN'),
#  ('green', 'NN'),
#  ('eggs', 'NN'),
#  ('and', 'NN'),
#  ('ham', 'NN'),
#  (',', 'NN'),
#  ('I', 'NN'),
#  ('do', 'NN'),
#  ('not', 'NN'),
#  ('like', 'NN'),
#  ('them', 'NN'),
#  ('Sam', 'NN'),
#  ('I', 'NN'),
#  ('am', 'NN'),
#  ('!', 'NN')]

# %%
default_tagger.evaluate(brown_tagged_sents)
# Out:
# 0.13089484257215028

# %%
patterns = [
 (r'.*ing$', 'VBG'), # gerunds
 (r'.*ed$', 'VBD'), # simple past
 (r'.*es$', 'VBZ'), # 3rd singular present
 (r'.*ould$', 'MD'), # modals
 (r'.*\'s$', 'NN$'), # possessive nouns
 (r'.*s$', 'NNS'), # plural nouns
 (r'^-?[0-9]+(.[0-9]+)?$', 'CD'), # cardinal numbers
 (r'.*', 'NN') # nouns (default)
 ]

# %%
regexp_tagger = nltk.RegexpTagger(patterns)
regexp_tagger.tag(brown_sents[3])
# Out:
# [('``', 'NN'),
#  ('Only', 'NN'),
#  ('a', 'NN'),
#  ('relative', 'NN'),
#  ('handful', 'NN'),
#  ('of', 'NN'),
#  ('such', 'NN'),
#  ('reports', 'NNS'),
#  ('was', 'NNS'),
#  ('received', 'VBD'),
#  ("''", 'NN'),
#  (',', 'NN'),
#  ('the', 'NN'),
#  ('jury', 'NN'),
#  ('said', 'NN'),
#  (',', 'NN'),
#  ('``', 'NN'),
#  ('considering', 'VBG'),
#  ('the', 'NN'),
#  ('widespread', 'NN'),
#  ('interest', 'NN'),
#  ('in', 'NN'),
#  ('the', 'NN'),
#  ('election', 'NN'),
#  (',', 'NN'),
#  ('the', 'NN'),
#  ('number', 'NN'),
#  ('of', 'NN'),
#  ('voters', 'NNS'),
#  ('and', 'NN'),
#  ('the', 'NN'),
#  ('size', 'NN'),
#  ('of', 'NN'),
#  ('this', 'NNS'),
#  ('city', 'NN'),
#  ("''", 'NN'),
#  ('.', 'NN')]

# %%
regexp_tagger.evaluate(brown_tagged_sents)
# Out:
# 0.20326391789486245

# %%
from nltk.tag import hmm
train_data = brown_tagged_sents[:100]
tagger = nltk.HiddenMarkovModelTagger.train(train_data)

# %% [markdown]
# to increase the result i increse the training to 3000 but it will take longer time to run

# %%
import numpy as np
np.int=np.int32

# %%
tagger.evaluate(brown_tagged_sents[100:])
# Out:
# 0.5802657550414098
